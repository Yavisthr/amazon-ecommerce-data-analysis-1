# %% [markdown]
# <a href="https://colab.research.google.com/github/Yavisthr/amazon-ecommerce-data-analysis-1/blob/main/Kids_Toys_Amazon_e_Commerce_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

raw_df = pd.read_csv('Kids Toys Helium 10 Export.csv')

# %%
raw_df.head()
# Out:
#    Display Order                                    Product Details  \
# 0            1.0  Amazon Echo Dot Kids with Alexa (newest model)...
# 1            2.0  ($) Fuwidvia 3 Pack Airplane Launcher Toys, 13...
# 2            3.0  ($) 3 Pack Airplane Launcher Toy, 12.6" Foam G...
# 3            4.0  ($) LCD Writing Tablet Doodle Board, 10.5 inch...
# 4            5.0  ($) KOKODI LCD Writing Tablet, Valentines Day ...
#
#          ASIN                                         URL  \
# 0  B09B9CD1YB  https://www.amazon.com/dp/B09B9CD1YB?psc=1
# 1  B09TDP1HCV  https://www.amazon.com/dp/B09TDP1HCV?psc=1
# 2  B09SZ1SSJT  https://www.amazon.com/dp/B09SZ1SSJT?psc=1
# 3  B09XB44G6G  https://www.amazon.com/dp/B09XB44G6G?psc=1
# 4  B082KFTF41  https://www.amazon.com/dp/B082KFTF41?psc=1
#
#                                            Image URL     Brand  Price  $  \
# 0  https://m.media-amazon.com/images/I/61K9vHlhKl...    Amazon     59.99
# 1  https://m.media-amazon.com/images/I/71Vex+UqD4...  Fuwidvia     26.99
# 2  https://m.media-amazon.com/images/I/71R-fBFD9p...  Aiencsai     26.99
# 3  https://m.media-amazon.com/images/I/71LuvjPN-G...    BUKEBU     14.99
# 4  https://m.media-amazon.com/images/I/71JXJ0I9e-...    KOKODI     19.99
#
#   Parent Level Sales ASIN Sales Recent Purchases  ...            Size Tier  \
# 0              6,004      4,952            4,000  ...  Large Standard-Size
# 1             13,471     12,252           10,000  ...  Large Standard-Size
# 2              2,981      2,550            1,000  ...  Large Standard-Size
# 3              1,526        552              500  ...  Small Standard-Size
# 4              5,580      2,132            1,000  ...  Small Standard-Size
#
#   Fulfillment              Dimensions Weight ABA Most Clicked  Creation Date  \
# 0         AMZ   6.02 x 3.90 x 4.25 in   1.23              NaN   Sep 28, 2022
# 1         FBA  13.50 x 2.40 x 7.72 in   0.64              NaN    May 9, 2022
# 2         FBA  13.63 x 2.32 x 7.96 in   0.65              NaN   Mar 28, 2022
# 3         FBA  10.47 x 0.55 x 7.40 in   0.53              NaN    Apr 6, 2022
# 4         FBA  11.26 x 0.75 x 7.60 in   0.44              NaN    Dec 9, 2019
#
#                Sponsored  Best Seller Seller Age (mo)         Seller
# 0  Featured Amazon Brand           No              33         Amazon
# 1              Sponsored          Yes              37      Yuanchina
# 2              Sponsored           No              39      Licaptain
# 3              Sponsored           No              38  LEVENIS Store
# 4              Sponsored           No              66        MUYBIEN
#
# [5 rows x 33 columns]

# %% [markdown]
# # New Section

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Display Order          70 non-null     float64
#  1   Product Details        70 non-null     object
#  2   ASIN                   70 non-null     object
#  3   URL                    70 non-null     object
#  4   Image URL              70 non-null     object
#  5   Brand                  70 non-null     object
#  6   Price  $               70 non-null     float64
#  7   Parent Level Sales     70 non-null     object
#  8   ASIN Sales             70 non-null     object
#  9   Recent Purchases       68 non-null     object
#  10  Parent Level Revenue   70 non-null     object
#  11  ASIN Revenue           70 non-null     object
#  12  Title Char. Count      70 non-null     int64
#  13  BSR                    68 non-null     object
#  14  Seller Country/Region  65 non-null     object
#  15  Fees  $                70 non-null     float64
#  16  Active Sellers         70 non-null     int64
#  17  Ratings                70 non-null     float64
#  18  Review Count           70 non-null     object
#  19  Images                 70 non-null     int64
#  20  Review velocity        67 non-null     float64
#  21  Buy Box                70 non-null     object
#  22  Category               67 non-null     object
#  23  Size Tier              70 non-null     object
#  24  Fulfillment            70 non-null     object
#  25  Dimensions             70 non-null     object
#  26  Weight                 70 non-null     float64
#  27  ABA Most Clicked       0 non-null      float64
#  28  Creation Date          70 non-null     object
#  29  Sponsored              22 non-null     object
#  30  Best Seller            70 non-null     object
#  31  Seller Age (mo)        70 non-null     int64
#  32  Seller                 70 non-null     object
# dtypes: float64(7), int64(4), object(22)
# memory usage: 18.2+ KB

# %%
excluded_columns = ['Display Order', 'Image URL', 'Parent Level Sales', 'Parent Level Revenue', 'Dimensions', 'Weight', 'ABA Most Clicked', 'Creation Date']
filtered_df = raw_df.drop(columns=excluded_columns)
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product Details        70 non-null     object
#  1   ASIN                   70 non-null     object
#  2   URL                    70 non-null     object
#  3   Brand                  70 non-null     object
#  4   Price  $               70 non-null     float64
#  5   ASIN Sales             70 non-null     object
#  6   Recent Purchases       68 non-null     object
#  7   ASIN Revenue           70 non-null     object
#  8   Title Char. Count      70 non-null     int64
#  9   BSR                    68 non-null     object
#  10  Seller Country/Region  65 non-null     object
#  11  Fees  $                70 non-null     float64
#  12  Active Sellers         70 non-null     int64
#  13  Ratings                70 non-null     float64
#  14  Review Count           70 non-null     object
#  15  Images                 70 non-null     int64
#  16  Review velocity        67 non-null     float64
#  17  Buy Box                70 non-null     object
#  18  Category               67 non-null     object
#  19  Size Tier              70 non-null     object
#  20  Fulfillment            70 non-null     object
#  21  Sponsored              22 non-null     object
#  22  Best Seller            70 non-null     object
#  23  Seller Age (mo)        70 non-null     int64
#  24  Seller                 70 non-null     object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 13.8+ KB

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product Details        70 non-null     object
#  1   ASIN                   70 non-null     object
#  2   URL                    70 non-null     object
#  3   Brand                  70 non-null     object
#  4   Price  $               70 non-null     float64
#  5   ASIN Sales             70 non-null     object
#  6   Recent Purchases       68 non-null     object
#  7   ASIN Revenue           70 non-null     object
#  8   Title Char. Count      70 non-null     int64
#  9   BSR                    68 non-null     object
#  10  Seller Country/Region  65 non-null     object
#  11  Fees  $                70 non-null     float64
#  12  Active Sellers         70 non-null     int64
#  13  Ratings                70 non-null     float64
#  14  Review Count           70 non-null     object
#  15  Images                 70 non-null     int64
#  16  Review velocity        67 non-null     float64
#  17  Buy Box                70 non-null     object
#  18  Category               67 non-null     object
#  19  Size Tier              70 non-null     object
#  20  Fulfillment            70 non-null     object
#  21  Sponsored              22 non-null     object
#  22  Best Seller            70 non-null     object
#  23  Seller Age (mo)        70 non-null     int64
#  24  Seller                 70 non-null     object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 13.8+ KB

# %%
filtered_df.head()
# Out:
#                                      Product Details        ASIN  \
# 0  Amazon Echo Dot Kids with Alexa (newest model)...  B09B9CD1YB
# 1  ($) Fuwidvia 3 Pack Airplane Launcher Toys, 13...  B09TDP1HCV
# 2  ($) 3 Pack Airplane Launcher Toy, 12.6" Foam G...  B09SZ1SSJT
# 3  ($) LCD Writing Tablet Doodle Board, 10.5 inch...  B09XB44G6G
# 4  ($) KOKODI LCD Writing Tablet, Valentines Day ...  B082KFTF41
#
#                                           URL     Brand  Price  $ ASIN Sales  \
# 0  https://www.amazon.com/dp/B09B9CD1YB?psc=1    Amazon     59.99      4,952
# 1  https://www.amazon.com/dp/B09TDP1HCV?psc=1  Fuwidvia     26.99     12,252
# 2  https://www.amazon.com/dp/B09SZ1SSJT?psc=1  Aiencsai     26.99      2,550
# 3  https://www.amazon.com/dp/B09XB44G6G?psc=1    BUKEBU     14.99        552
# 4  https://www.amazon.com/dp/B082KFTF41?psc=1    KOKODI     19.99      2,132
#
#   Recent Purchases ASIN Revenue  Title Char. Count    BSR  ... Images  \
# 0            4,000   224,012.31                127    114  ...      6
# 1           10,000   330,565.48                186    119  ...      6
# 2            1,000    63,471.05                172  2,215  ...      8
# 3              500     7,947.23                171  2,924  ...      7
# 4            1,000    42,588.66                192    439  ...      9
#
#    Review velocity        Buy Box      Category            Size Tier  \
# 0              0.0         Amazon           NaN  Large Standard-Size
# 1            125.0      Yuanchina  Toys & Games  Large Standard-Size
# 2             37.0      Licaptain  Toys & Games  Large Standard-Size
# 3             53.0  LEVENIS Store  Toys & Games  Small Standard-Size
# 4            138.0        MUYBIEN  Toys & Games  Small Standard-Size
#
#    Fulfillment              Sponsored Best Seller Seller Age (mo)  \
# 0          AMZ  Featured Amazon Brand          No              33
# 1          FBA              Sponsored         Yes              37
# 2          FBA              Sponsored          No              39
# 3          FBA              Sponsored          No              38
# 4          FBA              Sponsored          No              66
#
#           Seller
# 0         Amazon
# 1      Yuanchina
# 2      Licaptain
# 3  LEVENIS Store
# 4        MUYBIEN
#
# [5 rows x 25 columns]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product Details        70 non-null     object
#  1   ASIN                   70 non-null     object
#  2   URL                    70 non-null     object
#  3   Brand                  70 non-null     object
#  4   Price  $               70 non-null     float64
#  5   ASIN Sales             70 non-null     object
#  6   Recent Purchases       68 non-null     object
#  7   ASIN Revenue           70 non-null     object
#  8   Title Char. Count      70 non-null     int64
#  9   BSR                    68 non-null     object
#  10  Seller Country/Region  65 non-null     object
#  11  Fees  $                70 non-null     float64
#  12  Active Sellers         70 non-null     int64
#  13  Ratings                70 non-null     float64
#  14  Review Count           70 non-null     object
#  15  Images                 70 non-null     int64
#  16  Review velocity        67 non-null     float64
#  17  Buy Box                70 non-null     object
#  18  Category               67 non-null     object
#  19  Size Tier              70 non-null     object
#  20  Fulfillment            70 non-null     object
#  21  Sponsored              22 non-null     object
#  22  Best Seller            70 non-null     object
#  23  Seller Age (mo)        70 non-null     int64
#  24  Seller                 70 non-null     object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 13.8+ KB

# %%
columns_to_convert = ['ASIN Sales', 'Recent Purchases', 'ASIN Revenue', 'BSR', 'Review Count', 'Review velocity']

for column in columns_to_convert:
    # Replace 'N/A' with np.nan (NaN represents null in pandas)
    filtered_df[column] = filtered_df[column].replace('N/A', np.nan)

    # remove commas from the string values
    filtered_df[column] = filtered_df[column].astype(str).str.replace(',', '', regex=False)

    # convert to float, coercing errors to NaN
    filtered_df[column] = pd.to_numeric(filtered_df[column], errors='coerce')

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product Details        70 non-null     object
#  1   ASIN                   70 non-null     object
#  2   URL                    70 non-null     object
#  3   Brand                  70 non-null     object
#  4   Price  $               70 non-null     float64
#  5   ASIN Sales             70 non-null     int64
#  6   Recent Purchases       68 non-null     float64
#  7   ASIN Revenue           70 non-null     float64
#  8   Title Char. Count      70 non-null     int64
#  9   BSR                    68 non-null     float64
#  10  Seller Country/Region  65 non-null     object
#  11  Fees  $                70 non-null     float64
#  12  Active Sellers         70 non-null     int64
#  13  Ratings                70 non-null     float64
#  14  Review Count           70 non-null     int64
#  15  Images                 70 non-null     int64
#  16  Review velocity        67 non-null     float64
#  17  Buy Box                70 non-null     object
#  18  Category               67 non-null     object
#  19  Size Tier              70 non-null     object
#  20  Fulfillment            70 non-null     object
#  21  Sponsored              22 non-null     object
#  22  Best Seller            70 non-null     object
#  23  Seller Age (mo)        70 non-null     int64
#  24  Seller                 70 non-null     object
# dtypes: float64(7), int64(6), object(12)
# memory usage: 13.8+ KB

# %% [markdown]
# ,

# %%
filtered_df.describe()
# Out:
#          Price  $    ASIN Sales  Recent Purchases  ASIN Revenue  \
# count   70.000000     70.000000         68.000000  7.000000e+01
# mean    30.016571   8192.357143       6870.588235  2.125387e+05
# std     48.157443   6944.202996       5912.295784  4.036610e+05
# min      3.590000      6.000000        200.000000  1.259300e+02
# 25%     12.237500   2576.250000       2000.000000  4.417208e+04
# 50%     21.490000   6707.000000       6500.000000  1.202497e+05
# 75%     29.440000  12287.250000      10000.000000  2.427214e+05
# max    339.900000  32740.000000      30000.000000  2.548947e+06
#
#        Title Char. Count            BSR     Fees  $  Active Sellers  \
# count          70.000000      68.000000   70.000000       70.000000
# mean          159.885714    3386.235294   11.402429        6.171429
# std            33.480058   17551.372054   17.969682       10.389475
# min            46.000000       4.000000    1.500000        1.000000
# 25%           145.250000     118.500000    5.852500        1.000000
# 50%           168.500000     267.500000    9.165000        3.000000
# 75%           186.000000    1055.750000   10.270000        5.000000
# max           200.000000  143967.000000  143.300000       53.000000
#
#          Ratings  Review Count     Images  Review velocity  Seller Age (mo)
# count  70.000000     70.000000  70.000000        67.000000        70.000000
# mean    4.524286  12257.342857   7.771429       114.925373        61.028571
# std     0.190678  14157.174161   1.745980        83.533937        51.458713
# min     4.000000     20.000000   3.000000         0.000000         3.000000
# 25%     4.400000   2411.000000   7.000000        51.000000        27.250000
# 50%     4.600000   6657.000000   7.000000       108.000000        45.000000
# 75%     4.600000  16883.250000   9.000000       148.000000        78.250000
# max     4.800000  64290.000000  14.000000       408.000000       225.000000

# %%
# Fill empty 'Category' with 'Unknown'
filtered_df['Category'].fillna('Unknown', inplace=True)

# Group by 'Category' and sum 'ASIN Revenue'
category_revenue = filtered_df.groupby('Category')['ASIN Revenue'].sum().reset_index()

# Print the result
category_revenue
# Out:
# /tmp/ipython-input-60-1375931810.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   filtered_df['Category'].fillna('Unknown', inplace=True)
#             Category  ASIN Revenue
# 0  Sports & Outdoors     308753.26
# 1       Toys & Games   14263150.06
# 2            Unknown     305806.29

# %%
filtered_df = filtered_df[filtered_df['Category'].isin(['Toys & Games', 'Sports & Outdoors'])]
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67 entries, 1 to 69
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product Details        67 non-null     object
#  1   ASIN                   67 non-null     object
#  2   URL                    67 non-null     object
#  3   Brand                  67 non-null     object
#  4   Price  $               67 non-null     float64
#  5   ASIN Sales             67 non-null     int64
#  6   Recent Purchases       66 non-null     float64
#  7   ASIN Revenue           67 non-null     float64
#  8   Title Char. Count      67 non-null     int64
#  9   BSR                    67 non-null     float64
#  10  Seller Country/Region  62 non-null     object
#  11  Fees  $                67 non-null     float64
#  12  Active Sellers         67 non-null     int64
#  13  Ratings                67 non-null     float64
#  14  Review Count           67 non-null     int64
#  15  Images                 67 non-null     int64
#  16  Review velocity        64 non-null     float64
#  17  Buy Box                67 non-null     object
#  18  Category               67 non-null     object
#  19  Size Tier              67 non-null     object
#  20  Fulfillment            67 non-null     object
#  21  Sponsored              20 non-null     object
#  22  Best Seller            67 non-null     object
#  23  Seller Age (mo)        67 non-null     int64
#  24  Seller                 67 non-null     object
# dtypes: float64(7), int64(6), object(12)
# memory usage: 13.6+ KB

# %%
# Select only numerical columns (float64 and int64)
numerical_cols = filtered_df.select_dtypes(include=np.number).columns

# Create box plots for each numerical column
plt.figure(figsize=(10, 15))
for i, col in enumerate(numerical_cols):
    plt.subplot(len(numerical_cols), 1, i+1)  # Adjust subplot grid as needed
    sns.boxplot(x=filtered_df[col])
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
# Scatter plot of Ratings vs Review Count
plt.figure(figsize=(10, 6))
sns.scatterplot(data=filtered_df, x='Review Count', y='Ratings')
plt.title('Ratings vs Review Count')
plt.xlabel('Review Count')
plt.ylabel('Rating')
plt.show()

# %%
# Scatter plot of Ratings vs ASIN Revenue
plt.figure(figsize=(10, 6))
sns.scatterplot(data=filtered_df, x='ASIN Revenue', y='Ratings')
plt.title('Ratings vs ASIN Revenue')
plt.xlabel('ASIN Revenue')
plt.ylabel('Rating')
plt.show()

# %%
# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(data=filtered_df, x='Title Char. Count', y='ASIN Revenue', scatter_kws={'s':10})
plt.title('Title Character Count vs ASIN Revenue with Regression Line')
plt.xlabel('Title Character Count')
plt.ylabel('ASIN Revenue')
plt.show()

# %%
# Scatter plot of ASIN Revenue vs Title Char. Count
plt.figure(figsize=(10, 6))
sns.regplot(data=filtered_df, x='ASIN Revenue', y='Title Char. Count', scatter_kws={'s':10})
plt.title('ASIN Revenue vs Title Character Count with Regression Line')
plt.xlabel('ASIN Revenue')
plt.ylabel('Title Character Count')
plt.show()

# %%
# prompt: Scatterplot regrssion line of Ratings vs ASIN Revenue

plt.figure(figsize=(10, 6))
sns.regplot(data=filtered_df, x='ASIN Revenue', y='Ratings', scatter_kws={'s':10})
plt.title('Ratings vs ASIN Revenue with Regression Line')
plt.xlabel('ASIN Revenue')
plt.ylabel('Rating')
plt.show()

# %%
# prompt: # prompt: Scatterplot regrssion line of Ratings, Images, and Seller Age vs ASIN Revenue by fullfillment
x_vars = ['Ratings', 'Images', 'Seller Age (mo)']
y_var = 'ASIN Revenue'
legend_var = 'Fulfillment'

# Create a loop to generate scatter plots with regression lines for each x-variable and fulfillment type
for x_var in x_vars:
    plt.figure(figsize=(10, 6))
    for fulfillment_type in filtered_df[legend_var].unique():
        subset_df = filtered_df[filtered_df[legend_var] == fulfillment_type]
        sns.regplot(data=subset_df, x=x_var, y=y_var, scatter_kws={'s':10}, label=fulfillment_type)

    plt.title(f'{x_var} vs {y_var} with Regression Line by {legend_var}')
    plt.xlabel(x_var)
    plt.ylabel(y_var)
    plt.legend(title=legend_var)
    plt.show()

# %%
# prompt: export the filtered df for me adn label it pre-processing dataset

filtered_df.to_csv('pre-processing_dataset.csv', index=False)
